# %% [markdown]
# <a href="https://colab.research.google.com/github/marionrion/dsc-data-serialization-lab/blob/master/pokeman.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('pokemon.csv')

print(df)
# Out:
#      Number        Name   Type_1  Type_2  Total   HP  Attack  Defense  Sp_Atk  \
# 0         1   Bulbasaur    Grass  Poison    318   45      49       49      65
# 1         2     Ivysaur    Grass  Poison    405   60      62       63      80
# 2         3    Venusaur    Grass  Poison    525   80      82       83     100
# 3         4  Charmander     Fire     NaN    309   39      52       43      60
# 4         5  Charmeleon     Fire     NaN    405   58      64       58      80
# ..      ...         ...      ...     ...    ...  ...     ...      ...     ...
# 716     717     Yveltal     Dark  Flying    680  126     131       95     131
# 717     718     Zygarde   Dragon  Ground    600  108     100      121      81
# 718     719     Diancie     Rock   Fairy    600   50     100      150     100
# 719     720       Hoopa  Psychic   Ghost    600   80     110       60     150
# 720     721   Volcanion     Fire   Water    600   80     110      120     130
#
# ...

# %%
df.head()
# Out:
#    Number        Name Type_1  Type_2  Total  HP  Attack  Defense  Sp_Atk  \
# 0       1   Bulbasaur  Grass  Poison    318  45      49       49      65
# 1       2     Ivysaur  Grass  Poison    405  60      62       63      80
# 2       3    Venusaur  Grass  Poison    525  80      82       83     100
# 3       4  Charmander   Fire     NaN    309  39      52       43      60
# 4       5  Charmeleon   Fire     NaN    405  58      64       58      80
#
#    Sp_Def  ...  Color  hasGender  Pr_Male Egg_Group_1  Egg_Group_2  \
# 0      65  ...  Green       True    0.875     Monster        Grass
# 1      80  ...  Green       True    0.875     Monster        Grass
# 2     100  ...  Green       True    0.875     Monster        Grass
# 3      50  ...    Red       True    0.875     Monster       Dragon
# 4      65  ...    Red       True    0.875     Monster       Dragon
#
#    hasMegaEvolution Height_m Weight_kg  Catch_Rate      Body_Style
# ...

# %%
df.tail()
# Out:
#      Number       Name   Type_1  Type_2  Total   HP  Attack  Defense  Sp_Atk  \
# 716     717    Yveltal     Dark  Flying    680  126     131       95     131
# 717     718    Zygarde   Dragon  Ground    600  108     100      121      81
# 718     719    Diancie     Rock   Fairy    600   50     100      150     100
# 719     720      Hoopa  Psychic   Ghost    600   80     110       60     150
# 720     721  Volcanion     Fire   Water    600   80     110      120     130
#
#      Sp_Def  ...   Color  hasGender  Pr_Male   Egg_Group_1  Egg_Group_2  \
# 716      98  ...     Red      False      NaN  Undiscovered          NaN
# 717      95  ...   Green      False      NaN  Undiscovered          NaN
# 718     150  ...    Pink      False      NaN  Undiscovered          NaN
# 719     130  ...  Purple      False      NaN  Undiscovered          NaN
# 720      90  ...   Brown      False      NaN  Undiscovered          NaN
#
#      hasMegaEvolution Height_m Weight_kg  Catch_Rate       Body_Style
# ...

# %%
df.dtypes
# Out:
# Number                int64
# Name                 object
# Type_1               object
# Type_2               object
# Total                 int64
# HP                    int64
# Attack                int64
# Defense               int64
# Sp_Atk                int64
# Sp_Def                int64
# Speed                 int64
# Generation            int64
# isLegendary            bool
# Color                object
# hasGender              bool
# Pr_Male             float64
# Egg_Group_1          object
# Egg_Group_2          object
# hasMegaEvolution       bool
# Height_m            float64
# Weight_kg           float64
# Catch_Rate            int64
# Body_Style           object
# dtype: object

# %%
df.to_excel('pokemon.xlsx')

# %%
df.describe()
# Out:
#           Number       Total          HP      Attack     Defense      Sp_Atk  \
# count  721.00000  721.000000  721.000000  721.000000  721.000000  721.000000
# mean   361.00000  417.945908   68.380028   75.013870   70.808599   68.737864
# std    208.27906  109.663671   25.848272   28.984475   29.296558   28.788005
# min      1.00000  180.000000    1.000000    5.000000    5.000000   10.000000
# 25%    181.00000  320.000000   50.000000   53.000000   50.000000   45.000000
# 50%    361.00000  424.000000   65.000000   74.000000   65.000000   65.000000
# 75%    541.00000  499.000000   80.000000   95.000000   85.000000   90.000000
# max    721.00000  720.000000  255.000000  165.000000  230.000000  154.000000
#
#            Sp_Def       Speed  Generation     Pr_Male    Height_m   Weight_kg  \
# count  721.000000  721.000000  721.000000  644.000000  721.000000  721.000000
# mean    69.291262   65.714286    3.323162    0.553377    1.144979   56.773370
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 721 entries, 0 to 720
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Number            721 non-null    int64
#  1   Name              721 non-null    object
#  2   Type_1            721 non-null    object
#  3   Type_2            350 non-null    object
#  4   Total             721 non-null    int64
#  5   HP                721 non-null    int64
#  6   Attack            721 non-null    int64
#  7   Defense           721 non-null    int64
#  8   Sp_Atk            721 non-null    int64
#  9   Sp_Def            721 non-null    int64
#  10  Speed             721 non-null    int64
#  11  Generation        721 non-null    int64
#  12  isLegendary       721 non-null    bool
#  13  Color             721 non-null    object
#  14  hasGender         721 non-null    bool
#  15  Pr_Male           644 non-null    float64
# ...

# %%
df.columns
# Out:
# Index(['Number', 'Name', 'Type_1', 'Type_2', 'Total', 'HP', 'Attack',
#        'Defense', 'Sp_Atk', 'Sp_Def', 'Speed', 'Generation', 'isLegendary',
#        'Color', 'hasGender', 'Pr_Male', 'Egg_Group_1', 'Egg_Group_2',
#        'hasMegaEvolution', 'Height_m', 'Weight_kg', 'Catch_Rate',
#        'Body_Style'],
#       dtype='object')

# %%
df['Number']
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 716    717
# 717    718
# 718    719
# 719    720
# 720    721
# Name: Number, Length: 721, dtype: int64

# %%
df['Name'][0:5]
# Out:
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# Name: Name, dtype: object

# %%
df.iloc[0,3]
# Out:
# 'Poison'

# %%
df.loc[df.Name == 'Bulbasaur']
# Out:
#    Number       Name Type_1  Type_2  Total  HP  Attack  Defense  Sp_Atk  \
# 0       1  Bulbasaur  Grass  Poison    318  45      49       49      65
#
#    Sp_Def  ...  Color  hasGender  Pr_Male Egg_Group_1  Egg_Group_2  \
# 0      65  ...  Green       True    0.875     Monster        Grass
#
#    hasMegaEvolution Height_m Weight_kg  Catch_Rate  Body_Style
# 0             False     0.71       6.9          45   quadruped
#
# [1 rows x 23 columns]

# %%
df['Total'] > 100
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 716    True
# 717    True
# 718    True
# 719    True
# 720    True
# Name: Total, Length: 721, dtype: bool

# %%
df.drop(columns = ['Total'])
# Out:
#      Number        Name   Type_1  Type_2   HP  Attack  Defense  Sp_Atk  \
# 0         1   Bulbasaur    Grass  Poison   45      49       49      65
# 1         2     Ivysaur    Grass  Poison   60      62       63      80
# 2         3    Venusaur    Grass  Poison   80      82       83     100
# 3         4  Charmander     Fire     NaN   39      52       43      60
# 4         5  Charmeleon     Fire     NaN   58      64       58      80
# ..      ...         ...      ...     ...  ...     ...      ...     ...
# 716     717     Yveltal     Dark  Flying  126     131       95     131
# 717     718     Zygarde   Dragon  Ground  108     100      121      81
# 718     719     Diancie     Rock   Fairy   50     100      150     100
# 719     720       Hoopa  Psychic   Ghost   80     110       60     150
# 720     721   Volcanion     Fire   Water   80     110      120     130
#
#      Sp_Def  Speed  ...   Color  hasGender Pr_Male   Egg_Group_1  Egg_Group_2  \
# ...

# %%
df.drop(columns = ['HP', 'Attack', 'Defense', 'Total'])
# Out:
#      Number        Name   Type_1  Type_2  Sp_Atk  Sp_Def  Speed  Generation  \
# 0         1   Bulbasaur    Grass  Poison      65      65     45           1
# 1         2     Ivysaur    Grass  Poison      80      80     60           1
# 2         3    Venusaur    Grass  Poison     100     100     80           1
# 3         4  Charmander     Fire     NaN      60      50     65           1
# 4         5  Charmeleon     Fire     NaN      80      65     80           1
# ..      ...         ...      ...     ...     ...     ...    ...         ...
# 716     717     Yveltal     Dark  Flying     131      98     99           6
# 717     718     Zygarde   Dragon  Ground      81      95     95           6
# 718     719     Diancie     Rock   Fairy     100     150     50           6
# 719     720       Hoopa  Psychic   Ghost     150     130     70           6
# 720     721   Volcanion     Fire   Water     130      90     70           6
#
# ...

# %%
df.to_csv('updated.csv')

# %%
new_df = df.reset_index(drop=False)

# %%
df.to_csv('updated.csv')
